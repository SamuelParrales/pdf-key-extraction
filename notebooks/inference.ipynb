# %%
import os
import sys
from pathlib import Path
ROOT = Path().resolve()
while ROOT.name != "pdf-key-extraction":
    ROOT = ROOT.parent

sys.path.insert(0, str(ROOT / "src"))
os.chdir(ROOT)

# %%
from extract.key_value_extractor import KeyValueExtractor
extractor = KeyValueExtractor()
pdf_path = Path('evaluate/pdfs/1706202601139174848500120080200000490960004909618.pdf')

predict = extractor.predict(pdf_path)

print(predict)
# Out:
# {'form': [{'field': 'R.U.C.:', 'value': '1391748485001', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1391748485001', 'score': 1536.06}]}, {'field': 'No.', 'value': '008-020-000049096', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '008-020-000049096', 'score': 1594.56}]}, {'field': 'NÚMERO DE AUTORIZACIÓN', 'value': '1706202601139174848500120080200000490960004909618', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1706202601139174848500120080200000490960004909618', 'score': 1319.5}]}, {'field': 'FECHA Y HORA DE AUTORIZACIÓN:', 'value': datetime.datetime(2026, 6, 17, 10, 20, 2), 'value_type': 'FIELD_VALUE_DATE', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': datetime.datetime(2026, 6, 17, 10, 20, 2), 'score': 1531.05}]}, {'field': 'AMBIENTE:', 'value': 'PRODUCCIÓN', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'PRODUCCIÓN', 'score': 1521.05}]}, {'field': 'Dirección Matriz:', 'value': 'KM 3.5 VIA PORTOVIEJO-CRUCITA', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'KM 3.5 VIA PORTOVIEJO-CRUCITA', 'score': 1542.42}]}, {'field': 'EMISIÓN:', 'value': 'NORMAL', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'NORMAL', 'score': 1532.56}]}, {'field': 'Dirección Sucursal:', 'value': 'PANAMERICANA S/N Y BOLIVAR', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'PANAMERICANA S/N Y BOLIVAR', 'score': 1548.19}]}, {'field': 'Contribuyente Especial', 'value': '0011', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '0011', 'score': 1577.06}]}, {'field': 'OBLIGADO A LLEVAR CONTABILIDAD', 'value': 'SI', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'SI', 'score': 1475.56}]}, {'field': 'Agente de Retención Resolución No.', 'value': '1', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1', 'score': 1467.56}]}, {'field': 'Razón Social / Nombres y Apellidos:', 'value': 'SAMUEL  PARRALES PALMA', 'value_type': 'FIELD_VALUE_NAME', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'SAMUEL  PARRALES PALMA', 'score': 1392.55}]}, {'field': 'Identificación', 'value': '1315478162', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1315478162', 'score': 1584.06}]}, {'field': 'Fecha', 'value': datetime.datetime(2026, 6, 17, 0, 0), 'value_type': 'FIELD_VALUE_DATE', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': datetime.datetime(2026, 6, 17, 0, 0), 'score': 1567.05}]}, {'field': 'Direccion:', 'value': 'MONTECRISTI', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'MONTECRISTI', 'score': 1567.56}]}, {'field': 'SUBTOTAL 15%', 'value': 9.75, 'value_type': 'FIELD_VALUE_AMOUNT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 9.75, 'score': 1423.06}]}, {'field': 'IdTransaccion:', 'value': '1923311', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1923311', 'score': 1543.56}]}, {'field': 'SUBTOTAL NO OBJETO DE IVA', 'value': 0.0, 'value_type': 'FIELD_VALUE_AMOUNT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 0.0, 'score': 1466.06}]}, {'field': 'SUBTOTAL EXENTO DE IVA', 'value': 0.0, 'value_type': 'FIELD_VALUE_AMOUNT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 0.0, 'score': 1456.56}]}, {'field': 'Oficina:', 'value': '1', 'valu ...
