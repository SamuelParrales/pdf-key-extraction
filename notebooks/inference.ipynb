# %%
import os
import sys
from pathlib import Path
ROOT = Path().resolve()
while ROOT.name != "pdf-key-extraction":
    ROOT = ROOT.parent

sys.path.insert(0, str(ROOT / "src"))
os.chdir(ROOT)

# %%
from extract.key_value_extractor import KeyValueExtractor
extractor = KeyValueExtractor()

# %%
pdf_path = Path('evaluate/pdfs/1106202601139174848500120080200000487350004873513.pdf')

predict = extractor.predict(pdf_path)

print(predict)
# Out:
# c:\Users\Samuel\miniconda3\envs\pdf-key-extraction\Lib\site-packages\transformers\modeling_utils.py:1051: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# {'form': [{'field': 'R.U.C.:', 'value': '1391748485001', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1391748485001', 'score': 2039.0}, {'value': '008-020-000048735', 'score': 1902.76}, {'value': '1106202601139174848500120080200000487350004873513', 'score': 1811.6}]}, {'field': 'No.', 'value': '008-020-000048735', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '008-020-000048735', 'score': 2097.5}, {'value': '1106202601139174848500120080200000487350004873513', 'score': 1817.54}]}, {'field': 'NÚMERO DE AUTORIZACIÓN', 'value': '1106202601139174848500120080200000487350004873513', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1106202601139174848500120080200000487350004873513', 'score': 1905.28}]}, {'field': 'FECHA Y HORA DE AUTORIZACIÓN:', 'value': '11/06/2026 16:51:06', 'value_type': 'FIELD_VALUE_DATE', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '11/06/2026 16:51:06', 'score': 2033.99}]}, {'field': 'AMBIENTE:', 'value': 'PRODUCCIÓN', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'PRODUCCIÓN', 'score': 2024.0}]}, {'field': 'Dirección Matriz:', 'value': 'KM 3.5 VIA PORTOVIEJO-CRUCITA', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'KM 3.5 VIA PORTOVIEJO-CRUCITA', 'score': 2045.36}, {'value': 'PANAMERICANA S/N Y BOLIVAR', 'score': 1849.07}]}, {'field': 'EMISIÓN:', 'value': 'NORMAL', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'NORMAL', 'score': 2035.5}]}, {'field': 'Dirección Sucursal:', 'value': 'PANAMERICANA S/N Y BOLIVAR', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'PANAMERICANA S/N Y BOLIVAR', 'score': 2051.13}]}, {'field': 'Contribuyente Especial', 'value': '0011', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '0011', 'score': 2080.0}]}, {'field': 'OBLIGADO A LLEVAR CONTABILIDAD', 'value': 'SI', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'SI', 'score': 1978.5}]}, {'field': 'Agente de Retención Resolución No.', 'value': '1', 'value_type': 'FIELD_VALUE_TEXT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1', 'score': 1970.5}]}, {'field': 'Razón Social / Nombres y Apellidos:', 'value': 'SAMUEL  PARRALES PALMA', 'value_type': 'FIELD_VALUE_NAME', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'SAMUEL  PARRALES PALMA', 'score': 1895.5}]}, {'field': 'Identificación', 'value': '1315478162', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1315478162', 'score': 2087.0}]}, {'field': 'Fecha', 'value': '11/06/2026', 'value_type': 'FIELD_VALUE_DATE', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '11/06/2026', 'score': 2070.0}]}, {'field': 'Direccion:', 'value': 'MONTECRISTI', 'value_type': 'FIELD_VALUE_ADDRESS', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': 'MONTECRISTI', 'score': 2070.5}]}, {'field': 'SUBTOTAL 15%', 'value': '67.61', 'value_type': 'FIELD_VALUE_AMOUNT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '67.61', 'score': 1929.5}]}, {'field': 'SUBTOTAL NO OBJETO DE IVA', 'value': '0.00', 'value_type': 'FIELD_VALUE_AMOUNT', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '0.00', 'score': 1969.0}]}, {'field': 'IdTransaccion:', 'value': '1914529', 'value_type': 'FIELD_VALUE_ID', 'is_reliable': True, 'selected_by': 'heuristic', 'candidates': [{'value': '1914529', 'score': 2046.5}]}, {'field': 'SUBTOTAL EXENTO DE IVA', 'value': ...
